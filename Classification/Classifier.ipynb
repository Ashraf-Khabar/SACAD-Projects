# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis, QuadraticDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.model_selection import cross_val_score

# %%
# Load data
data_app = pd.read_csv('data_app.csv').values
etats_app = pd.read_csv('etats_app.csv').values.ravel()

# %%
lda = LinearDiscriminantAnalysis()
lda.fit(data_app, etats_app)
# Out:
# LinearDiscriminantAnalysis()

# %%
plt.figure(figsize=(8, 6))
plt.scatter(data_app[:, 0], data_app[:, 1], c=etats_app, cmap='viridis', edgecolors='k', marker='o', s=80)
plt.title('Linear Discriminant Analysis Decision Boundaries')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')

# Plot decision boundaries
h = .02
x_min, x_max = data_app[:, 0].min() - 1, data_app[:, 0].max() + 1
y_min, y_max = data_app[:, 1].min() - 1, data_app[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
Z = lda.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)
plt.contour(xx, yy, Z, levels=[0], linewidths=2, colors='red')
plt.show()

# %%
qda = QuadraticDiscriminantAnalysis()
qda.fit(data_app, etats_app)
# Out:
# QuadraticDiscriminantAnalysis()

# %%
plt.figure(figsize=(8, 6))
plt.scatter(data_app[:, 0], data_app[:, 1], c=etats_app, cmap='viridis', edgecolors='k', marker='o', s=80)
plt.title('Quadratic Discriminant Analysis Decision Boundaries')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')

# Plot decision boundaries
Z = qda.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)
plt.contour(xx, yy, Z, levels=[0], linewidths=2, colors='red')
plt.show()

# %%
# 4) Gaussian Naive Bayes
nb = GaussianNB()
nb.fit(data_app, etats_app)

# Visualize decision boundaries for Gaussian Naive Bayes
plt.figure(figsize=(8, 6))
plt.scatter(data_app[:, 0], data_app[:, 1], c=etats_app, cmap='viridis', edgecolors='k', marker='o', s=80)
plt.title('Gaussian Naive Bayes Decision Boundaries')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')

# Plot decision boundaries
Z = nb.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)
plt.contour(xx, yy, Z, levels=[0], linewidths=2, colors='red')
plt.show()

# %%
# 5) Decision Tree
tree = DecisionTreeClassifier()
tree.fit(data_app, etats_app)
# Out:
# DecisionTreeClassifier()

# %%
# Visualize decision boundaries for Decision Tree
plt.figure(figsize=(8, 6))
plt.scatter(data_app[:, 0], data_app[:, 1], c=etats_app, cmap='viridis', edgecolors='k', marker='o', s=80)
plt.title('Decision Tree Decision Boundaries')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
# Plot decision boundaries
Z = tree.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)
plt.contour(xx, yy, Z, levels=[0], linewidths=2, colors='red')
plt.show()

# %%
# SVM (Linear Kernel)
svm_linear = SVC(kernel='linear')
svm_linear.fit(data_app, etats_app)
# Out:
# SVC(kernel='linear')

# %%
# Visualize decision boundaries for SVM (Linear Kernel)
plt.figure(figsize=(8, 6))
plt.scatter(data_app[:, 0], data_app[:, 1], c=etats_app, cmap='viridis', edgecolors='k', marker='o', s=80)
plt.title('SVM (Linear Kernel) Decision Boundaries')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')

# Plot decision boundaries
Z = svm_linear.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)
plt.contour(xx, yy, Z, levels=[0], linewidths=2, colors='red')
plt.show()

# %%
# SVM (Gaussian Kernel)
svm_rbf = SVC(kernel='rbf')
svm_rbf.fit(data_app, etats_app)
# Out:
# SVC()

# %%
# Visualize decision boundaries for SVM (Gaussian Kernel)
plt.figure(figsize=(8, 6))
plt.scatter(data_app[:, 0], data_app[:, 1], c=etats_app, cmap='viridis', edgecolors='k', marker='o', s=80)
plt.title('SVM (Gaussian Kernel) Decision Boundaries')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')

# Plot decision boundaries
Z = svm_rbf.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)
plt.contour(xx, yy, Z, levels=[0], linewidths=2, colors='red')
plt.show()
